# %%
import numpy as np

# %%
tmp_data = np.load("/home/suncz/work/part1/code/nmibenchmark/LLM/NT/500m-human/GM12878/dna_embeddings.npz")

# %%
for i in tmp_data.keys():
    print(i)
# Out:
# contigs
# embeddings

# %%
tmp_data["contigs"]
# Out:
# array([['chr1', '9846', '10246', '1'],
#        ['chr1', '10007', '10407', '1'],
#        ['chr1', '10400', '10800', '1'],
#        ...,
#        ['chr4', '69740344', '69740744', '0'],
#        ['chr1', '189491000', '189491400', '0'],
#        ['chr6', '134313784', '134314184', '0']], dtype='<U21')

# %%
189491400 - 189491000
# Out:
# 400

# %%
embeddings = tmp_data['embeddings']

# %%
embeddings.shape
# Out:
# (447742, 1280)

# %%
tmp_data = np.load("/home/suncz/work/part1/code/nmibenchmark/LLM/DNABERT2/GM12878/train_test_data.npz",allow_pickle=True)

# %%
tmp_data["train_data"][0]
# Out:
# array([ 4.85791676e-02,  1.61685586e-01,  6.07566424e-02,  1.67630494e-01,
#        -2.62119938e-02, -1.45661607e-01, -1.50351718e-01,  1.71250291e-02,
#        -1.19046435e-01, -7.26479515e-02, -5.64102568e-02, -2.74471026e-02,
#        -5.66814467e-02, -2.60181129e-01, -1.38088897e-01,  2.32711062e-02,
#        -2.87310869e-01, -1.09394729e-01,  2.51328740e-02, -7.01197684e-02,
#         6.10904880e-02,  1.42837420e-01, -2.26974767e-02,  1.44557044e-01,
#         2.16092885e-01,  1.69734925e-01,  1.08822742e-02, -8.68557778e-04,
#        -1.30432129e-01, -5.87669089e-02, -1.01724975e-02,  3.25588644e-01,
#        -5.01288399e-02, -5.24285622e-02,  1.20855190e-01,  1.14599720e-01,
#        -1.76874787e-01, -1.01845883e-01, -1.42783672e-01,  3.01785529e-01,
#        -1.98718846e-01,  1.74084559e-01, -3.64119075e-02, -6.14167331e-03,
#         8.07850584e-02, -3.27311009e-02,  1.44051373e-01, -5.88233545e-02,
# ...

# %%
tmp_data["train_data"][2049]
# Out:
# array([-6.48400337e-02,  9.41530541e-02,  4.38973643e-02, -7.50784427e-02,
#        -8.55022892e-02, -5.41843921e-02, -1.11981928e-01, -1.36953816e-01,
#         4.29307669e-02,  5.22231720e-02,  2.01629214e-02,  5.95606538e-03,
#        -5.34466468e-03, -1.18685216e-01, -1.11907922e-01,  4.32722978e-02,
#        -7.66745582e-02,  8.84055793e-02, -6.46780282e-02, -4.65309881e-02,
#        -1.57360034e-03,  3.32645439e-02,  9.71657038e-03, -4.87064496e-02,
#         6.82367384e-02,  5.24994321e-02,  2.38615707e-01,  3.32566001e-03,
#        -1.96953584e-02, -6.68493733e-02,  1.59735307e-02,  5.65617643e-02,
#        -1.20923027e-01, -3.14218812e-02, -5.16882166e-02,  4.59020846e-02,
#        -1.41330764e-01,  2.20919698e-02,  5.36855832e-02, -9.02933925e-02,
#        -1.83273479e-01,  2.40356196e-02, -3.79931144e-02, -7.56130964e-02,
#         5.58125302e-02, -4.27518077e-02, -7.17131421e-02, -1.19209196e-02,
# ...
